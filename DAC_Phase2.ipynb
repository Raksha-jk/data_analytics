# %%
import pandas as pd
website_data=pd.read_csv("D:\Data Analytics\daily-website-visitors.csv")
print(website_data)
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
data=pd.read_csv("D:\Data Analytics\daily-website-visitors.csv")
data.head()
# Out:
#    Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0    1     Sunday            1  9/14/2014      2,146         1,582
# 1    2     Monday            2  9/15/2014      3,621         2,528
# 2    3    Tuesday            3  9/16/2014      3,698         2,630
# 3    4  Wednesday            4  9/17/2014      3,667         2,614
# 4    5   Thursday            5  9/18/2014      3,316         2,366
#
#   First.Time.Visits Returning.Visits
# 0             1,430              152
# 1             2,297              231
# 2             2,352              278
# 3             2,327              287
# 4             2,130              236

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# Row                  0
# Day                  0
# Day.Of.Week          0
# Date                 0
# Page.Loads           0
# Unique.Visits        0
# First.Time.Visits    0
# Returning.Visits     0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Page.Loads'])
plt.title("Distribution of users of website in a particular week")
plt.show()

# %%
import plotly.express as px
px.histogram(data,x='Day',y='Unique.Visits',title='Sum of unique visits for each day over Time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:922, in __call__(self, obj)
#
# File c:\Users\Raksha J\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\Raksha J\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# ...
